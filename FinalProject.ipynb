# %% [markdown]
# <a href="https://colab.research.google.com/github/LarsonShane/CMSI-1010-Final-Project/blob/main/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')

# !pip install pybaseball
# Out:
# Requirement already satisfied: pybaseball in /usr/local/lib/python3.10/dist-packages (2.2.7)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (1.26.4)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (2.2.2)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (4.12.3)
# Requirement already satisfied: requests>=2.18.1 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (2.32.3)
# Requirement already satisfied: lxml>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (5.3.0)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (17.0.0)
# Requirement already satisfied: pygithub>=1.51 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (2.5.0)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (1.13.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (3.8.0)
# Requirement already satisfied: tqdm>=4.50.0 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (4.66.6)
# Requirement already satisfied: attrs>=20.3.0 in /usr/local/lib/python3.10/dist-packages (from pybaseball) (24.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pybaseball) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->pybaseball) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->pybaseball) (2024.2)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pygithub>=1.51->pybaseball) (1.5.0)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pygithub>=1.51->pybaseball) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pygithub>=1.51->pybaseball) (2.2.3)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from pygithub>=1.51->pybaseball) (1.2.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.1->pybaseball) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.1->pybaseball) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.1->pybaseball) (2024.8.30)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.22)

# %%
from pybaseball import standings
import pandas as pd
from datascience import *

from pybaseball import team_pitching
from pybaseball import team_batting

from pybaseball import pitching_stats
from pybaseball import batting_stats

# %%
class TeamStandings:
# The TeamStandings class allows the user to see the statistics on the Team Standings.
  def __init__(self):
    self.data = standings(2024)
    self.data = pd.concat(self.data)
    self.standings_table = Table.from_df(self.data)
    standings_table_df = self.standings_table.to_df()
    standings_table_df = standings_table_df.replace('--', '0.0', regex=True)
    standings_table_df['GB'] = pd.to_numeric(standings_table_df['GB'], errors='coerce')
    self.standings_table = Table.from_df(standings_table_df)

# The showTable function allows the user to see the table.
  def showTable(self):
    self.standings_table.show()

# The sortTable function sorts the table for the stat that the user wants.
  def sortTable(self, stat):
    sorted_Table = self.standings_table.sort(stat, descending=True)
    sorted_Table.show()

# The filterTable function filters the table with what the user wants and then sorts the stats that is being filtered.
  def filterTable(self, stat, low, high):
    filtered_table = self.standings_table.copy()
    filtered_table = filtered_table.where(0, are.equal_to(0))
    for row in self.standings_table.rows:
      num = row.item(stat)
      if low <= float(num) <= high:
        filtered_table.append(row)
    filtered_table = filtered_table.sort(stat, descending=True)
    filtered_table.show()

class TeamPitchingStats:
# The TeamPitchingStats class allows the user to see the statistics for each team's pitching.
  def __init__(self):
    self.data = team_pitching(2024)
    selected_columns = ['Team', 'W', 'L', 'ERA', 'CG', 'SV', 'BS', 'IP', 'H', 'BB', 'SO', 'WHIP']
    self.data = self.data[selected_columns]
    self.pitching_stats_table = Table.from_df(self.data)

# The showTable function allows the user to see the table.
  def showTable(self):
    self.pitching_stats_table.show()

# The sortTable function sorts the table for the stat that the user wants.
  def sortTable(self, stat):
    sorted_Table = self.pitching_stats_table.sort(stat, descending=True)
    sorted_Table.show()

# The filterTable function filters the table with what the user wants and then sorts the stats that is being filtered.
  def filterTable(self, stat, low, high):
    filtered_table = self.pitching_stats_table.copy()
    filtered_table = filtered_table.where(0, are.equal_to(0))
    for row in self.pitching_stats_table.rows:
      num = row.item(stat)
      if low <= float(num) <= high:
        filtered_table.append(row)
    filtered_table = filtered_table.sort(stat, descending=True)
    filtered_table.show()

class IndividualPitchingStats(TeamPitchingStats):
# The IndividualPitchingsStats class allows the user to see the statistics for each qualified player's pitching.
  def __init__(self):
    self.data = pitching_stats(2024)
    selected_columns = ['Team','Name', 'W', 'L', 'ERA', 'CG', 'IP', 'H', 'BB', 'SO', 'WHIP']
    self.data = self.data[selected_columns]
    self.pitching_stats_table = Table.from_df(self.data)

class TeamBattingStats:
# The TeamBattingStats class allows the user to see the statitsics for each team's batting.
  def __init__(self):
    self.data = team_batting(2024)
    selected_columns = ['Team', 'AB', 'PA', 'H', '2B', 'HR', 'R', 'RBI', 'BB', 'SO', 'HBP', 'SB', 'CS']
    self.data = self.data[selected_columns]
    self.batting_stats_table = Table.from_df(self.data)

# The showTable function allows the user to see the table.
  def showTable(self):
    self.batting_stats_table.show()

# The sortTable function sorts the table for the stat that the user wants.
  def sortTable(self, stat):
    sorted_Table = self.batting_stats_table.sort(stat, descending=True)
    sorted_Table.show()

# The filterTable function filters the table with what the user wants and then sorts the stats that is being filtered.
  def filterTable(self, stat, low, high):
    filtered_table = self.batting_stats_table.copy()
    filtered_table = filtered_table.where(0, are.equal_to(0))
    for row in self.batting_stats_table.rows:
      num = row.item(stat)
      if low <= float(num) <= high:
        filtered_table.append(row)
    filtered_table = filtered_table.sort(stat, descending=True)
    filtered_table.show()

class IndividualBattingStats(TeamBattingStats):
# The IndividualBattingStats class allows the user to see the statistics for each qualified player's batting.
  def __init__(self):
    self.data = batting_stats(2024)
    selected_columns = ['Team','Name', 'AB', 'PA', 'H', '2B', 'HR', 'R', 'RBI', 'BB', 'SO', 'HBP', 'SB', 'CS']
    self.data = self.data[selected_columns]
    self.batting_stats_table = Table.from_df(self.data)

# %%
Team_Standings_Table = TeamStandings()
Team_Pitching_Table = TeamPitchingStats()
Team_Batting_Table = TeamBattingStats()
Individual_Pitching_Table = IndividualPitchingStats()
Individual_Batting_Table = IndividualBattingStats()

# The process_standings function shows the user the standings table depending on how they want to sort and filter it.
def process_standings():
  Team_Standings_Table.showTable()
  input3 = input("Which stat do you want to sort by? (W/L/W-L%/GB/stop): ").upper()
  if input3.lower() == "stop":
    return
  Team_Standings_Table.sortTable(input3)
  input4 = input("In between what do you want to filter by? (lowerbound-higherbound/stop): ").lower()
  if input4.lower() == "stop":
    return
  lower_bound = float(input4.split("-")[0])
  higher_bound = float(input4.split("-")[1])
  Team_Standings_Table.filterTable(input3, lower_bound, higher_bound)

# The process_team_pitching function shows the user the team pitching table depending on how they want to sort and filter it.
def process_team_pitching():
  Team_Pitching_Table.showTable()
  input3 = input("Which stat do you want to sort by? (W/L/ERA/CG/SV/BS/IP/H/BB/SO/WHIP): ").upper()
  if input3.lower() == "stop":
    return
  Team_Pitching_Table.sortTable(input3)
  input4 = input("In between what do you want to filter by? (lowerbound-higherbound): ")
  if input4.lower() == "stop":
    return
  lower_bound = float(input4.split("-")[0])
  higher_bound = float(input4.split("-")[1])
  Team_Pitching_Table.filterTable(input3, lower_bound, higher_bound)

# The process_team_batting function shows the user the team batting table depending on how they want to sort and filter it.
def process_team_batting():
  Team_Batting_Table.showTable()
  input3 = input("Which stat do you want to sort by? (Team/AB/PA/H/2B/HR/R/RBI/BB/SO/HBP/SB/CS): ").upper()
  if input3.lower() == "stop":
    return
  Team_Batting_Table.sortTable(input3)
  input4 = input("In between what do you want to filter by? (lowerbound-higherbound): ")
  if input4.lower() == "stop":
    return
  lower_bound = float(input4.split("-")[0])
  higher_bound = float(input4.split("-")[1])
  Team_Standings_Table.filterTable(input3, lower_bound, higher_bound)

# The process_individual_pitching function shows the user the individual pitching table depending on how they want to sort and filter it.
def process_individual_pitching():
  Individual_Pitching_Table.showTable()
  input3 = input("Which stat do you want to sort by? (W/L/ERA/CG/IP/H/BB/SO/WHIP): ").upper()
  if input3.lower() == "stop":
    return
  Individual_Pitching_Table.sortTable(input3)
  input4 = input("In between what do you want to filter by? (lowerbound-higherbound): ")
  if input4.lower() == "stop":
    return
  lower_bound = float(input4.split("-")[0])
  higher_bound = float(input4.split("-")[1])
  Individual_Pitching_Table.filterTable(input3, lower_bound, higher_bound)

# The process_individual_batting function shows the user the individual batting table depending on how they want to sort and filter it.
def process_individual_batting():
  Individual_Batting_Table.showTable()
  input3 = input("Which stat do you want to sort by? (Team/AB/PA/H/2B/HR/R/RBI/BB/SO/HBP/SB/CS): ").upper()
  if input3.lower() == "stop":
    return
  Individual_Batting_Table.sortTable(input3)
  input4 = input("In between what do you want to filter by? (lowerbound-higherbound): ")
  if input4.lower() == "stop":
    return
  lower_bound = float(input4.split("-")[0])
  higher_bound = float(input4.split("-")[1])
  Individual_Standings_Table.filterTable(input3, lower_bound, higher_bound)

# %%
input1 = input("Do you want to look at Team or Individual stats? (Team/Individual): ").lower()
if input1 == "team":
  input2 = input("Do you want to look at Standings, Pitching, or Batting stats? (Standings/Pitching/Batting): ").lower()
  if input2 == "standings":
    process_standings()
  elif input2 == "pitching":
    process_team_pitching()
  elif input2 == "batting":
    process_team_batting()
elif input1 == "individual":
  input2 = input("Do you want to look at Pitching or Batting stats? (Pitching/Batting): ").lower()
  if input2 == "pitching":
    process_individual_pitching()
  elif input2 == "batting":
    process_individual_batting()
# Out:
# Do you want to look at Team or Individual stats? (Team/Individual): individual
# Do you want to look at Pitching or Batting stats? (Pitching/Batting): batting
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Team</th> <th>Name</th> <th>AB</th> <th>PA</th> <th>H</th> <th>2B</th> <th>HR</th> <th>R</th> <th>RBI</th> <th>BB</th> <th>SO</th> <th>HBP</th> <th>SB</th> <th>CS</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>NYY  </td> <td>Aaron Judge          </td> <td>559 </td> <td>704 </td> <td>180 </td> <td>36  </td> <td>58  </td> <td>122 </td> <td>144 </td> <td>133 </td> <td>171 </td> <td>9   </td> <td>10  </td> <td>0   </td>
#         </tr>
#         <tr>
#             <td>KCR  </td> <td>Bobby Witt Jr.       </td> <td>636 </td> <td>709 </td> <td>211 </td> <td>45  </td> <td>32  </td> <td>125 </td> <td>109 </td> <td>57  </td> <td>106 </td> <td>8   </td> <td>31  </td> <td>12  </td>
#         </tr>
#         <tr>
#             <td>LAD  </td> <td>Shohei Ohtani        </td> <td>636 </td> <td>731 </td> <td>197 </td> <td>38  </td> <td>54  </td> <td>134 </td> <td>130 </td> <td>81  </td> <td>162 </td> <td>6   </td> <td>59  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>NYY  </td> <td>Juan Soto            </td> <td>576 </td> <td>713 </td> <td>166 </td> <td>31  </td> <td>41  </td> <td>128 </td> <td>109 </td> <td>129 </td> <td>119 </td> <td>4   </td> <td>7   </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>BAL  </td> <td>Gunnar Henderson     </td> <td>630 </td> <td>719 </td> <td>177 </td> <td>31  </td> <td>37  </td> <td>118 </td> <td>92  </td> <td>78  </td> <td>159 </td> <td>7   </td> <td>21  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>NYM  </td> <td>Francisco Lindor     </td> <td>618 </td> <td>689 </td> <td>169 </td> <td>39  </td> <td>33  </td> <td>107 </td> <td>91  </td> <td>56  </td> <td>127 </td> <td>12  </td> <td>29  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>BOS  </td> <td>Jarren Duran         </td> <td>671 </td> <td>735 </td> <td>191 </td> <td>48  </td> <td>21  </td> <td>111 </td> <td>75  </td> <td>54  </td> <td>160 </td> <td>6   </td> <td>34  </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>CLE  </td> <td>Jose Ramirez         </td> <td>620 </td> <td>682 </td> <td>173 </td> <td>39  </td> <td>39  </td> <td>114 </td> <td>118 </td> <td>54  </td> <td>82  </td> <td>1   </td> <td>41  </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>CIN  </td> <td>Elly De La Cruz      </td> <td>618 </td> <td>696 </td> <td>160 </td> <td>36  </td> <td>25  </td> <td>105 </td> <td>76  </td> <td>69  </td> <td>218 </td> <td>6   </td> <td>67  </td> <td>16  </td>
#         </tr>
#         <tr>
#             <td>ARI  </td> <td>Ketel Marte          </td> <td>504 </td> <td>583 </td> <td>147 </td> <td>23  </td> <td>36  </td> <td>93  </td> <td>95  </td> <td>65  </td> <td>106 </td> <td>5   </td> <td>7   </td> <td>1   </td>
#         </tr>
#         <tr>
#             <td>TOR  </td> <td>Vladimir Guerrero Jr.</td> <td>616 </td> <td>697 </td> <td>199 </td> <td>44  </td> <td>30  </td> <td>98  </td> <td>103 </td> <td>72  </td> <td>96  </td> <td>5   </td> <td>2   </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>SFG  </td> <td>Matt Chapman         </td> <td>575 </td> <td>647 </td> <td>142 </td> <td>39  </td> <td>27  </td> <td>98  </td> <td>78  </td> <td>64  </td> <td>158 </td> <td>6   </td> <td>15  </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>MIL  </td> <td>William Contreras    </td> <td>595 </td> <td>679 </td> <td>167 </td> <td>37  </td> <td>23  </td> <td>99  </td> <td>92  </td> <td>78  </td> <td>139 </td> <td>3   </td> <td>9   </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>SEA  </td> <td>Cal Raleigh          </td> <td>546 </td> <td>628 </td> <td>120 </td> <td>16  </td> <td>34  </td> <td>73  </td> <td>100 </td> <td>70  </td> <td>176 </td> <td>6   </td> <td>6   </td> <td>1   </td>
#         </tr>
#         <tr>
#             <td>HOU  </td> <td>Yordan Alvarez       </td> <td>552 </td> <td>635 </td> <td>170 </td> <td>34  </td> <td>35  </td> <td>88  </td> <td>86  </td> <td>69  </td> <td>95  </td> <td>10  </td> <td>6   </td> <td>0   </td>
#         </tr>
#         <tr>
#             <td>SDP  </td> <td>Jackson Merrill      </td> <td>554 </td> <td>593 </td> <td>162 </td> <td>31  </td> <td>24  </td> <td>77  </td> <td>90  </td> <td>29  </td> <td>101 </td> <td>1   </td> <td>16  </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>PHI  </td> <td>Bryce Harper         </td> <td>550 </td> <td>631 </td> <td>157 </td> <td>42  </td> <td>30  </td> <td>85  </td> <td>87  </td> <td>76  </td> <td>138 </td> <td>2   </td> <td>7   </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>OAK  </td> <td>Brent Rooker         </td> <td>546 </td> <td>614 </td> <td>160 </td> <td>26  </td> <td>39  </td> <td>82  </td> <td>112 </td> <td>59  </td> <td>177 </td> <td>5   </td> <td>11  </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>MIL  </td> <td>Willy Adames         </td> <td>610 </td> <td>688 </td> <td>153 </td> <td>33  </td> <td>32  </td> <td>93  </td> <td>112 </td> <td>74  </td> <td>173 </td> <td>1   </td> <td>21  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>ATL  </td> <td>Marcell Ozuna        </td> <td>606 </td> <td>688 </td> <td>183 </td> <td>31  </td> <td>39  </td> <td>96  </td> <td>104 </td> <td>74  </td> <td>170 </td> <td>3   </td> <td>1   </td> <td>0   </td>
#         </tr>
#         <tr>
#             <td>TEX  </td> <td>Corey Seager         </td> <td>475 </td> <td>533 </td> <td>132 </td> <td>21  </td> <td>30  </td> <td>68  </td> <td>74  </td> <td>53  </td> <td>96  </td> <td>3   </td> <td>1   </td> <td>1   </td>
#         </tr>
#         <tr>
#             <td>LAD  </td> <td>Mookie Betts         </td> <td>450 </td> <td>516 </td> <td>130 </td> <td>24  </td> <td>19  </td> <td>75  </td> <td>75  </td> <td>61  </td> <td>57  </td> <td>1   </td> <td>16  </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>SDP  </td> <td>Jurickson Profar     </td> <td>564 </td> <td>668 </td> <td>158 </td> <td>29  </td> <td>24  </td> <td>94  </td> <td>85  </td> <td>76  </td> <td>101 </td> <td>18  </td> <td>10  </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>CHC  </td> <td>Dansby Swanson       </td> <td>534 </td> <td>593 </td> <td>129 </td> <td>27  </td> <td>16  </td> <td>82  </td> <td>66  </td> <td>54  </td> <td>144 </td> <td>2   </td> <td>19  </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>TEX  </td> <td>Marcus Semien        </td> <td>650 </td> <td>718 </td> <td>154 </td> <td>27  </td> <td>23  </td> <td>101 </td> <td>74  </td> <td>64  </td> <td>105 </td> <td>3   </td> <td>8   </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>BOS  </td> <td>Rafael Devers        </td> <td>525 </td> <td>601 </td> <td>143 </td> <td>34  </td> <td>28  </td> <td>87  </td> <td>83  </td> <td>67  </td> <td>147 </td> <td>3   </td> <td>3   </td> <td>0   </td>
#         </tr>
#         <tr>
#             <td>CLE  </td> <td>Steven Kwan          </td> <td>480 </td> <td>540 </td> <td>140 </td> <td>16  </td> <td>14  </td> <td>83  </td> <td>44  </td> <td>53  </td> <td>51  </td> <td>5   </td> <td>12  </td> <td>5   </td>
#         </tr>
#         <tr>
#             <td>HOU  </td> <td>Alex Bregman         </td> <td>581 </td> <td>634 </td> <td>151 </td> <td>30  </td> <td>26  </td> <td>79  </td> <td>75  </td> <td>44  </td> <td>86  </td> <td>5   </td> <td>3   </td> <td>1   </td>
#         </tr>
#         <tr>
#             <td>LAD  </td> <td>Freddie Freeman      </td> <td>542 </td> <td>638 </td> <td>153 </td> <td>35  </td> <td>22  </td> <td>81  </td> <td>89  </td> <td>78  </td> <td>100 </td> <td>10  </td> <td>9   </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>DET  </td> <td>Riley Greene         </td> <td>512 </td> <td>584 </td> <td>134 </td> <td>27  </td> <td>24  </td> <td>82  </td> <td>74  </td> <td>64  </td> <td>156 </td> <td>5   </td> <td>4   </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>BAL  </td> <td>Colton Cowser        </td> <td>499 </td> <td>561 </td> <td>121 </td> <td>24  </td
# Which stat do you want to sort by? (Team/AB/PA/H/2B/HR/R/RBI/BB/SO/HBP/SB/CS): SB
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Team</th> <th>Name</th> <th>AB</th> <th>PA</th> <th>H</th> <th>2B</th> <th>HR</th> <th>R</th> <th>RBI</th> <th>BB</th> <th>SO</th> <th>HBP</th> <th>SB</th> <th>CS</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>CIN  </td> <td>Elly De La Cruz      </td> <td>618 </td> <td>696 </td> <td>160 </td> <td>36  </td> <td>25  </td> <td>105 </td> <td>76  </td> <td>69  </td> <td>218 </td> <td>6   </td> <td>67  </td> <td>16  </td>
#         </tr>
#         <tr>
#             <td>LAD  </td> <td>Shohei Ohtani        </td> <td>636 </td> <td>731 </td> <td>197 </td> <td>38  </td> <td>54  </td> <td>134 </td> <td>130 </td> <td>81  </td> <td>162 </td> <td>6   </td> <td>59  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>MIL  </td> <td>Brice Turang         </td> <td>559 </td> <td>619 </td> <td>142 </td> <td>24  </td> <td>7   </td> <td>72  </td> <td>57  </td> <td>50  </td> <td>105 </td> <td>2   </td> <td>50  </td> <td>6   </td>
#         </tr>
#         <tr>
#             <td>CLE  </td> <td>Jose Ramirez         </td> <td>620 </td> <td>682 </td> <td>173 </td> <td>39  </td> <td>39  </td> <td>114 </td> <td>118 </td> <td>54  </td> <td>82  </td> <td>1   </td> <td>41  </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>- - -</td> <td>Jazz Chisholm Jr.    </td> <td>562 </td> <td>621 </td> <td>144 </td> <td>21  </td> <td>24  </td> <td>74  </td> <td>73  </td> <td>53  </td> <td>152 </td> <td>4   </td> <td>40  </td> <td>10  </td>
#         </tr>
#         <tr>
#             <td>KCR  </td> <td>Maikel Garcia        </td> <td>575 </td> <td>626 </td> <td>133 </td> <td>27  </td> <td>7   </td> <td>84  </td> <td>58  </td> <td>42  </td> <td>103 </td> <td>0   </td> <td>37  </td> <td>2   </td>
#         </tr>
#         <tr>
#             <td>ARI  </td> <td>Corbin Carroll       </td> <td>589 </td> <td>684 </td> <td>136 </td> <td>22  </td> <td>22  </td> <td>121 </td> <td>74  </td> <td>73  </td> <td>130 </td> <td>10  </td> <td>35  </td> <td>8   </td>
#         </tr>
#         <tr>
#             <td>BOS  </td> <td>Jarren Duran         </td> <td>671 </td> <td>735 </td> <td>191 </td> <td>48  </td> <td>21  </td> <td>111 </td> <td>75  </td> <td>54  </td> <td>160 </td> <td>6   </td> <td>34  </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>WSN  </td> <td>Jacob Young          </td> <td>468 </td> <td>521 </td> <td>120 </td> <td>24  </td> <td>3   </td> <td>75  </td> <td>36  </td> <td>30  </td> <td>102 </td> <td>12  </td> <td>33  </td> <td>10  </td>
#         </tr>
#         <tr>
#             <td>PHI  </td> <td>Bryson Stott         </td> <td>506 </td> <td>571 </td> <td>124 </td> <td>19  </td> <td>11  </td> <td>65  </td> <td>57  </td> <td>53  </td> <td>93  </td> <td>3   </td> <td>32  </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>- - -</td> <td>Lane Thomas          </td> <td>472 </td> <td>528 </td> <td>112 </td> <td>26  </td> <td>15  </td> <td>65  </td> <td>63  </td> <td>44  </td> <td>137 </td> <td>7   </td> <td>32  </td> <td>14  </td>
#         </tr>
#         <tr>
#             <td>KCR  </td> <td>Bobby Witt Jr.       </td> <td>636 </td> <td>709 </td> <td>211 </td> <td>45  </td> <td>32  </td> <td>125 </td> <td>109 </td> <td>57  </td> <td>106 </td> <td>8   </td> <td>31  </td> <td>12  </td>
#         </tr>
#         <tr>
#             <td>CHC  </td> <td>Nico Hoerner         </td> <td>582 </td> <td>641 </td> <td>159 </td> <td>35  </td> <td>7   </td> <td>86  </td> <td>48  </td> <td>44  </td> <td>66  </td> <td>12  </td> <td>31  </td> <td>6   </td>
#         </tr>
#         <tr>
#             <td>WSN  </td> <td>CJ Abrams            </td> <td>541 </td> <td>602 </td> <td>133 </td> <td>29  </td> <td>20  </td> <td>79  </td> <td>65  </td> <td>40  </td> <td>128 </td> <td>16  </td> <td>31  </td> <td>12  </td>
#         </tr>
#         <tr>
#             <td>COL  </td> <td>Brenton Doyle        </td> <td>542 </td> <td>603 </td> <td>141 </td> <td>24  </td> <td>23  </td> <td>82  </td> <td>72  </td> <td>46  </td> <td>153 </td> <td>3   </td> <td>30  </td> <td>5   </td>
#         </tr>
#         <tr>
#             <td>LAA  </td> <td>Zach Neto            </td> <td>542 </td> <td>602 </td> <td>135 </td> <td>34  </td> <td>23  </td> <td>70  </td> <td>77  </td> <td>39  </td> <td>140 </td> <td>16  </td> <td>30  </td> <td>10  </td>
#         </tr>
#         <tr>
#             <td>CLE  </td> <td>Andres Gimenez       </td> <td>583 </td> <td>633 </td> <td>147 </td> <td>22  </td> <td>9   </td> <td>64  </td> <td>63  </td> <td>26  </td> <td>97  </td> <td>15  </td> <td>30  </td> <td>5   </td>
#         </tr>
#         <tr>
#             <td>NYM  </td> <td>Francisco Lindor     </td> <td>618 </td> <td>689 </td> <td>169 </td> <td>39  </td> <td>33  </td> <td>107 </td> <td>91  </td> <td>56  </td> <td>127 </td> <td>12  </td> <td>29  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>NYY  </td> <td>Anthony Volpe        </td> <td>637 </td> <td>689 </td> <td>155 </td> <td>27  </td> <td>12  </td> <td>90  </td> <td>60  </td> <td>42  </td> <td>156 </td> <td>4   </td> <td>28  </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>OAK  </td> <td>Zack Gelof           </td> <td>497 </td> <td>547 </td> <td>105 </td> <td>20  </td> <td>17  </td> <td>60  </td> <td>49  </td> <td>38  </td> <td>188 </td> <td>4   </td> <td>25  </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>CIN  </td> <td>Spencer Steer        </td> <td>574 </td> <td>656 </td> <td>129 </td> <td>34  </td> <td>20  </td> <td>74  </td> <td>92  </td> <td>72  </td> <td>137 </td> <td>8   </td> <td>25  </td> <td>3   </td>
#         </tr>
#         <tr>
#             <td>SEA  </td> <td>Julio Rodriguez      </td> <td>567 </td> <td>613 </td> <td>155 </td> <td>17  </td> <td>20  </td> <td>76  </td> <td>68  </td> <td>38  </td> <td>156 </td> <td>6   </td> <td>24  </td> <td>5   </td>
#         </tr>
#         <tr>
#             <td>TEX  </td> <td>Leody Taveras        </td> <td>480 </td> <td>529 </td> <td>110 </td> <td>17  </td> <td>12  </td> <td>59  </td> <td>44  </td> <td>42  </td> <td>112 </td> <td>0   </td> <td>23  </td> <td>6   </td>
#         </tr>
#         <tr>
#             <td>MIL  </td> <td>Jackson Chourio      </td> <td>528 </td> <td>573 </td> <td>145 </td> <td>29  </td> <td>21  </td> <td>80  </td> <td>79  </td> <td>39  </td> <td>121 </td> <td>3   </td> <td>22  </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>HOU  </td> <td>Jose Altuve          </td> <td>628 </td> <td>682 </td> <td>185 </td> <td>31  </td> <td>20  </td> <td>94  </td> <td>65  </td> <td>47  </td> <td>119 </td> <td>7   </td> <td>22  </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>PIT  </td> <td>Oneil Cruz           </td> <td>541 </td> <td>599 </td> <td>140 </td> <td>34  </td> <td>21  </td> <td>72  </td> <td>76  </td> <td>51  </td> <td>181 </td> <td>3   </td> <td>22  </td> <td>1   </td>
#         </tr>
#         <tr>
#             <td>WSN  </td> <td>Luis Garcia Jr.      </td> <td>500 </td> <td>528 </td> <td>141 </td> <td>25  </td> <td>18  </td> <td>58  </td> <td>70  </td> <td>27  </td> <td>86  </td> <td>0   </td> <td>22  </td> <td>5   </td>
#         </tr>
#         <tr>
#             <td>BAL  </td> <td>Gunnar Henderson     </td> <td>630 </td> <td>719 </td> <td>177 </td> <td>31  </td> <td>37  </td> <td>118 </td> <td>92  </td> <td>78  </td> <td>159 </td> <td>7   </td> <td>21  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>MIL  </td> <td>Willy Adames         </td> <td>610 </td> <td>688 </td> <td>153 </td> <td>33  </td> <td>32  </td> <td>93  </td> <td>112 </td> <td>74  </td> <td>173 </td> <td>1   </td> <td>21  </td> <td>4   </td>
#         </tr>
#         <tr>
#             <td>HOU  </td> <td>Jeremy Pena          </td> <td>602 </td> <td>650 </td> <td>160 </td> <td>28  </td> <td>15  </td> <td>78  </td> <td>70  </td> <td>25  </td> <td>111 </td> <td>14  </td> <td>20  </td> <td>6   </td>
#         </tr>
#         <tr>
#             <td>- - -</td> <td>Randy Arozarena      </td> <td>549 </td> <td>648 </td> <td>120 </td> <td>33  </td
# In between what do you want to filter by? (lowerbound-higherbound): stop
